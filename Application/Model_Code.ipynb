# %% [markdown]
# # DATA UNDERSTANDING

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# ### 1. Dataset Kepesertaan

# %%
import pandas as pd

# Baca file .dta
file_path = "../Dataset/Kontekstual DM/DM2019_kepesertaan.dta"
dm = pd.read_stata(file_path)

# Menampilkan beberapa baris pertama dari dataset
dm.head()
# Out:
#       PSTV01     PSTV02     PSTV03   PSTV04     PSTV05 PSTV06   PSTV07  \
# 0   45243428   45243428 1959-10-11  PESERTA  PEREMPUAN  KAWIN  KELAS I
# 1  356470819  356470819 1965-12-31  PESERTA  LAKI-LAKI  KAWIN  KELAS I
# 2   72280409  375793382 1964-08-03    ISTRI  PEREMPUAN  CERAI  KELAS I
# 3   88501975   88501975 1959-10-02  PESERTA  PEREMPUAN  KAWIN  KELAS I
# 4   94870095  310527655 1947-01-01    SUAMI  LAKI-LAKI  KAWIN  KELAS I
#
#           PSTV08          PSTV09           PSTV10                     PSTV11  \
# 0            PPU            ACEH            PIDIE  PEMERINTAH KABUPATEN/KOTA
# 1            PPU            ACEH  KOTA BANDA ACEH  PEMERINTAH KABUPATEN/KOTA
# 2  BUKAN PEKERJA  SUMATERA UTARA        BATU BARA  PEMERINTAH KABUPATEN/KOTA
# 3            PPU  SUMATERA UTARA           ASAHAN  PEMERINTAH KABUPATEN/KOTA
# 4  BUKAN PEKERJA  SUMATERA BARAT  PESISIR SELATAN  PEMERINTAH KABUPATEN/KOTA
#
# ...

# %%
dm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143496 entries, 0 to 143495
# Data columns (total 18 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   PSTV01  143496 non-null  int32
#  1   PSTV02  143496 non-null  int32
#  2   PSTV03  143496 non-null  datetime64[ns]
#  3   PSTV04  143496 non-null  category
#  4   PSTV05  143496 non-null  category
#  5   PSTV06  143496 non-null  category
#  6   PSTV07  143496 non-null  category
#  7   PSTV08  143496 non-null  category
#  8   PSTV09  143496 non-null  category
#  9   PSTV10  143496 non-null  category
#  10  PSTV11  143496 non-null  category
#  11  PSTV12  143496 non-null  category
#  12  PSTV13  143496 non-null  category
#  13  PSTV14  143496 non-null  category
#  14  PSTV15  143496 non-null  float32
#  15  PSTV16  143496 non-null  int16
#  16  PSTV17  143496 non-null  category
#  17  PSTV18  10268 non-null   float64
# ...

# %%
import pandas as pd

# Baca file .dta
file_path = "../Dataset/Kontekstual DM/DM2020_kepesertaan.dta"  # Ganti dengan path file Anda
dm1 = pd.read_stata(file_path)

# Menampilkan beberapa baris pertama dari dataset
dm1.head()
# Out:
#      PSTV01    PSTV02     PSTV03   PSTV04     PSTV05 PSTV06    PSTV07  \
# 0  66897393  66897393 1955-12-31  PESERTA  LAKI-LAKI  CERAI  KELAS II
# 1  36947751  36947751 1957-01-01  PESERTA  LAKI-LAKI  KAWIN   KELAS I
# 2  58468881  58468881 1959-06-15  PESERTA  PEREMPUAN  KAWIN   KELAS I
# 3  67318251  67318251 1977-11-11  PESERTA  LAKI-LAKI  KAWIN  KELAS II
# 4  80155656  80155656 1961-12-31  PESERTA  PEREMPUAN  CERAI   KELAS I
#
#           PSTV08 PSTV09            PSTV10                     PSTV11  \
# 0            PPU   ACEH             PIDIE                     SWASTA
# 1  BUKAN PEKERJA   ACEH   KOTA BANDA ACEH                     SWASTA
# 2  BUKAN PEKERJA   ACEH       KOTA LANGSA  PEMERINTAH KABUPATEN/KOTA
# 3            PPU   ACEH  KOTA LHOKSEUMAWE  PEMERINTAH KABUPATEN/KOTA
# 4            PPU   ACEH           BIREUEN  PEMERINTAH KABUPATEN/KOTA
#
#            PSTV12 PSTV13            PSTV14     PSTV15  PSTV16 PSTV17  PSTV18
# ...

# %%
dm1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143496 entries, 0 to 143495
# Data columns (total 18 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   PSTV01  143496 non-null  int32
#  1   PSTV02  143496 non-null  int32
#  2   PSTV03  143496 non-null  datetime64[ns]
#  3   PSTV04  143496 non-null  category
#  4   PSTV05  143496 non-null  category
#  5   PSTV06  143496 non-null  category
#  6   PSTV07  143496 non-null  category
#  7   PSTV08  143496 non-null  category
#  8   PSTV09  143496 non-null  category
#  9   PSTV10  143496 non-null  category
#  10  PSTV11  143496 non-null  category
#  11  PSTV12  143496 non-null  category
#  12  PSTV13  143496 non-null  category
#  13  PSTV14  143496 non-null  category
#  14  PSTV15  143496 non-null  float32
#  15  PSTV16  143496 non-null  int16
#  16  PSTV17  143496 non-null  category
#  17  PSTV18  10268 non-null   float64
# ...

# %%
import pandas as pd

# Baca file .dta
file_path = "../Dataset/Kontekstual DM/DM2021_kepesertaan.dta" 
dm2 = pd.read_stata(file_path)

# Menampilkan beberapa baris pertama dari dataset
dm2.head()
# Out:
#      PSTV01    PSTV02     PSTV03   PSTV04     PSTV05 PSTV06    PSTV07  \
# 0  66897393  66897393 1955-12-31  PESERTA  LAKI-LAKI  CERAI  KELAS II
# 1  36947751  36947751 1957-01-01  PESERTA  LAKI-LAKI  KAWIN   KELAS I
# 2  58468881  58468881 1959-06-15  PESERTA  PEREMPUAN  KAWIN   KELAS I
# 3  67318251  67318251 1977-11-11  PESERTA  LAKI-LAKI  KAWIN  KELAS II
# 4  80155656  80155656 1961-12-31  PESERTA  PEREMPUAN  CERAI   KELAS I
#
#           PSTV08 PSTV09            PSTV10                     PSTV11  \
# 0            PPU   ACEH             PIDIE                     SWASTA
# 1  BUKAN PEKERJA   ACEH   KOTA BANDA ACEH                     SWASTA
# 2  BUKAN PEKERJA   ACEH       KOTA LANGSA  PEMERINTAH KABUPATEN/KOTA
# 3            PPU   ACEH  KOTA LHOKSEUMAWE  PEMERINTAH KABUPATEN/KOTA
# 4            PPU   ACEH           BIREUEN  PEMERINTAH KABUPATEN/KOTA
#
#            PSTV12 PSTV13            PSTV14     PSTV15  PSTV16 PSTV17  PSTV18
# ...

# %%
dm2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143496 entries, 0 to 143495
# Data columns (total 18 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   PSTV01  143496 non-null  int32
#  1   PSTV02  143496 non-null  int32
#  2   PSTV03  143496 non-null  datetime64[ns]
#  3   PSTV04  143496 non-null  category
#  4   PSTV05  143496 non-null  category
#  5   PSTV06  143496 non-null  category
#  6   PSTV07  143496 non-null  category
#  7   PSTV08  143496 non-null  category
#  8   PSTV09  143496 non-null  category
#  9   PSTV10  143496 non-null  category
#  10  PSTV11  143496 non-null  category
#  11  PSTV12  143496 non-null  category
#  12  PSTV13  143496 non-null  category
#  13  PSTV14  143496 non-null  category
#  14  PSTV15  143496 non-null  float32
#  15  PSTV16  143496 non-null  int16
#  16  PSTV17  143496 non-null  category
#  17  PSTV18  17679 non-null   float64
# ...

# %% [markdown]
# **Data Kepesertaan**
#
# Untuk dataset Kepersertaan 2019-2021 library pandas diimpor untuk mengelola data, kemudian file Kepersertaan 2019-2021 dimuat ke dalam DataFrame dm. Dataset Kepersertaan 2019-2021 mencakup data kepesertaan JKN-KIS tahun 2019-2021, termasuk informasi penting seperti nomor peserta (identifikasi unik untuk setiap peserta), tanggal lahir, jenis kelamin, status perkawinan, hubungan keluarga, dan tempat tinggal (provinsi dan kabupaten/kota). Kolom-kolom ini memungkinkan analisis demografi peserta untuk memahami profil populasi yang terdaftar pada tahun tersebut.
# Selanjutnya, menampilkan struktur data dm menggunakan dm.info(), yang memberikan informasi tentang jumlah baris, tipe data, serta keberadaan nilai kosong. Ini penting untuk memastikan bahwa data telah dikumpulkan dengan benar dan siap digunakan untuk analisis lebih lanjut.
# Berikut penjelasan tiap kolom dari dataset Kepersertaan 2019-2021 :
# - PSTV01 - Nomor peserta
#     Nomor identifikasi peserta yang bersifat unik dan telah dideidentifikasi untuk melindungi identitas peserta sebenarnya.
# - PSTV02 - Nomor keluarga
#     Nomor yang mengidentifikasi kepala keluarga dalam sampel, berfungsi sebagai penanda keluarga (peserta BPJS Kesehatan dalam satu keluarga memiliki nomor kepala keluarga yang sama).
# - PSTV03 - Tanggal lahir peserta
#     Tanggal lahir peserta yang tercatat pada sistem BPJS Kesehatan ketika mendaftar.
# - PSTV04 - Hubungan keluarga
#     Hubungan atau status peserta di dalam keluarga.
# - PSTV05 - Jenis kelamin
#     Jenis kelamin peserta, seperti "LAKI-LAKI" atau "PEREMPUAN".
# - PSTV06 - Status perkawinan
#     Status pernikahan peserta, seperti "KAWIN" atau "CERAI".
# - PSTV07 - Kelas rawat
#     Kelas rawat peserta yang tercatat dalam sistem BPJS Kesehatan per tanggal 31 Desember 2020.
# - PSTV08 - Segmentasi peserta
#     Segmentasi peserta yang tercatat pada sistem BPJS Kesehatan per tanggal 31 Desember 2020, seperti "PPU" (Pekerja Penerima Upah), "BUKAN PEKERJA".
# - PSTV09 - Provinsi tempat tinggal peserta
#     Provinsi tempat tinggal peserta yang diinput dalam sistem BPJS Kesehatan saat mendaftar (sesuai kode wilayah BPS).
# - PSTV10 - Kabupaten/Kota tempat tinggal peserta
#     Kabupaten/Kota tempat tinggal peserta yang diinput dalam sistem BPJS Kesehatan saat mendaftar (sesuai kode wilayah BPS).
# - PSTV11 - Kepemilikan faskes
#     Kepemilikan dari fasilitas kesehatan tempat peserta terdaftar.
# - PSTV12 - Jenis faskes
#     Jenis fasilitas kesehatan tempat peserta terdaftar, seperti "PUSKESMAS".
# - PSTV13 - Provinsi fasilitas kesehatan peserta terdaftar
#     Provinsi fasilitas kesehatan tempat peserta terdaftar (sesuai kode wilayah BPS).
# - PSTV14 - Kabupaten/Kota fasilitas kesehatan peserta terdaftar
#     Kabupaten/Kota fasilitas kesehatan tempat peserta terdaftar (sesuai kode wilayah BPS).
# - PSTV15 - Bobot
#     Faktor pengali yang menggambarkan jumlah individu di dalam populasi yang diwakili oleh individu dalam sampel.
# - PSTV16 - Tahun sampel
#     Tahun sampel diambil sebagai data kepesertaan.
# - PSTV17 - Status kepesertaan
#     Status kepesertaan berdasarkan sistem BPJS Kesehatan per tanggal 31 Desember 2020 (misalnya "AKTIF" atau "MENINGGAL").
# - PSTV18 - Tahun meninggal
#     Tahun peserta meninggal yang tercatat pada sistem BPJS Kesehatan.

# %% [markdown]
# ### 2. Dataset FKTP Kapitasi

# %%
import pandas as pd

file_path = "../Dataset/Kontekstual DM/DM2021_fktpkapitasi.dta"
dm3 = pd.read_stata(file_path, convert_categoricals=False)
dm3.head()
# Out:
#       PSTV01     PSTV02     PSTV15       FKP02      FKP03      FKP04  FKP05  \
# 0   12380560   12380560  13.364630  1687160334 2021-11-10 2021-11-10     31
# 1  288452470   78043385   8.494392  1457720536 2021-02-26 2021-02-26     17
# 2  337885189  337885189  13.472825  1732989007 2021-12-08 2021-12-08     31
# 3    2783323    2783323  12.233603  1464029376 2021-03-03 2021-03-03     32
# 4   99122276    6688304   6.842236  1646802901 2021-09-28 2021-09-28     52
#
#    FKP06  FKP07  FKP08  ...  FKP14A  FKP15  FKP15A  FKP16  FKP17  FKP18 FKP19  \
# 0   3174      3      1  ...           9999    9999     98   9998     98    98
# 1   1702      3      1  ...           9999    9999     98   9998     98    98
# 2   3175      3      1  ...           9999    9999     98   9998     98    98
# 3   3276      3      1  ...           9999    9999     98   9998     98    98
# 4   5272      3      1  ...           9999    9999     98   9998     98    98
#
#   FKP20 FKP21  FKP22
# ...

# %%
dm3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188324 entries, 0 to 1188323
# Data columns (total 26 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   PSTV01  1188324 non-null  int32
#  1   PSTV02  1188324 non-null  int32
#  2   PSTV15  1188324 non-null  float32
#  3   FKP02   1188324 non-null  object
#  4   FKP03   1188324 non-null  datetime64[ns]
#  5   FKP04   1188324 non-null  datetime64[ns]
#  6   FKP05   1188324 non-null  int8
#  7   FKP06   1188324 non-null  int16
#  8   FKP07   1188324 non-null  int8
#  9   FKP08   1188324 non-null  int8
#  10  FKP09   1188324 non-null  int8
#  11  FKP10   1188324 non-null  int8
#  12  FKP11   1188324 non-null  int8
#  13  FKP12   1188324 non-null  int8
#  14  FKP13   1188324 non-null  int8
#  15  FKP14   1188324 non-null  int16
#  16  FKP14A  1188324 non-null  object
#  17  FKP15   1188324 non-null  object
#  18  FKP15A  1188324 non-null  object
#  19  FKP16   1188324 non-null  int8
# ...

# %% [markdown]
# **Data fktp kapitasi**
#
# Untuk data pelayanan di FKTP dengan model kapitasi tahun 2021 dimuat ke dalam DataFrame dm3 dari file DM2021_fktpkapitasi.dta. Dataset ini mencakup informasi seperti nomor kunjungan, diagnosis ICD-10, jenis layanan, serta pola rujukan. Data ini berguna untuk menganalisis efektivitas pelayanan kesehatan yang diberikan melalui model pembayaran kapitasi.
# Selanjutnya, menampilkan informasi dari dm3 menggunakan dm3.info(), yang memvalidasi struktur data pelayanan di FKTP dan memastikan bahwa data siap untuk dianalisis.
# Berikut penjelasan tiap kolom dari dataset fktpkapitasi:
# - PSTV01 (Nomor peserta):
#     Nomor identifikasi peserta yang bersifat unik dan telah dideidentifikasi untuk melindungi identitas peserta sebenarnya.
# - PSTV02 (Nomor keluarga):
#     Nomor yang mengidentifikasi kepala keluarga dalam sampel dan berfungsi sebagai penanda keluarga (peserta BPJS Kesehatan dalam satu keluarga memiliki nomor kepala keluarga yang sama).
# - PSTV15 (Bobot):
#     Faktor pengali yang menggambarkan jumlah individu di dalam populasi yang diwakili oleh individu di dalam sampel.
# - FKP02 (ID Kunjungan FKTP):
#     Nomor identifikasi unik untuk menandakan setiap kunjungan FKTP oleh peserta.
# - FKP03 (Tanggal datang kunjungan FKTP):
#     Tanggal melakukan kunjungan FKTP.
# - FKP04 (Tanggal pulang kunjungan FKTP):
#     Tanggal menyelesaikan kunjungan FKTP.
# - FKP05 (Provinsi FKTP):
#     Provinsi tempat peserta mengakses fasilitas kesehatan (sesuai kode wilayah BPS).
# - FKP06 (Kabupaten/Kota FKTP):
#     Kabupaten/kota tempat peserta mengakses fasilitas kesehatan (sesuai kode wilayah BPS).
# - FKP07 (Kepemilikan FKTP):
#     Jenis kepemilikan fasilitas kesehatan yang diakses oleh peserta pada kunjungan FKTP.
# - FKP08 (Jenis FKTP):
#     Jenis fasilitas kesehatan yang diakses oleh peserta pada kunjungan FKTP.
# - FKP09 (Tipe FKTP):
#     Tipe fasilitas kesehatan yang diakses oleh peserta pada kunjungan FKTP.
# - FKP10 (Tingkat Pelayanan FKTP):
#     Tingkat layanan yang diakses oleh peserta pada kunjungan FKTP.
# - FKP11 (Jenis Poli FKTP):
#     Jenis poliklinik yang diakses oleh peserta pada kunjungan FKTP.
# - FKP12 (Segmen Peserta saat akses layanan FKTP):
#     Jenis segmen peserta saat peserta mengakses FKTP.
# - FKP13 (Status Kunjungan Peserta):
#     Status peserta di akhir masa perawatan.
# - FKP14 (Kode dan nama diagnosis ICD 10 - 3 digit):
#     Kode dan nama diagnosis berdasarkan 3 digit pertama kode ICD 10 yang diperoleh dari hasil input sistem informasi BPJS Kesehatan.
# - FKP14A (Kode diagnosis ICD 10 - 3 digit):
#     Kode diagnosis berdasarkan 3 digit pertama.
# - FKP15 (Kode diagnosis - beragam 3-5 digit):
#     Kode diagnosis hasil input di sistem BPJS Kesehatan berdasarkan kode ICD 10 (jumlah digit beragam pada semua observasi dengan rentang 3-5 digit).
# - FKP15A (Nama diagnosis berasal dari kode diagnosis):
#     Nama diagnosis yang terbaca oleh sistem BPJS Kesehatan berdasarkan kode diagnosis (FKP15) yang ter-input dalam sistem.
# - FKP16 (Provinsi faskes tujuan rujukan):
#     Provinsi fasilitas kesehatan tujuan rujukan (sesuai kode wilayah BPS).
# - FKP17 (Kabupaten/Kota faskes tujuan rujukan):
#     Kabupaten/kota fasilitas kesehatan tujuan rujukan (sesuai kode wilayah BPS).
# - FKP18 (Kepemilikan faskes tujuan rujukan):
#     Kepemilikan fasilitas kesehatan tujuan rujukan.
# - FKP19 (Jenis faskes tujuan rujukan):
#     Jenis fasilitas kesehatan tujuan rujukan.
# - FKP20 (Tipe faskes tujuan rujukan):
#     Tipe fasilitas kesehatan tujuan rujukan.
# - FKP21 (Poli faskes tujuan rujukan):
#     Poli fasilitas kesehatan tujuan rujukan.
# - FKP22 (Jenis Kunjungan FKTP):
#     Jenis kunjungan FKTP.

# %% [markdown]
# ### 3. FKTP Non Kapitasi

# %%
import pandas as pd

# Baca file .dta
file_path = "../Dataset/Kontekstual DM/DM2021_fktpnonkapitasi.dta" 
dm4 = pd.read_stata(file_path)

# Menampilkan beberapa baris pertama dari dataset
dm4.head()
# Out:
#       PSTV01     PSTV02     PSTV15             PNK02      PNK03      PNK04  \
# 0   88204825   88204825   6.755007  203960321P000052 2021-03-13 2021-03-16
# 1   24034617   72462276  12.832207  185630321P001651 2021-03-28 2021-03-28
# 2   17391573  417758463  13.106908   46631021P000693 2021-10-11 2021-10-14
# 3   60560444   60560444  12.762736  325900321P000146 2021-03-17 2021-03-21
# 4  291346266  291346266  13.404066  460570621P000056 2021-06-13 2021-06-16
#
#        PNK05                PNK06         PNK07                      PNK08  \
# 0 2021-03-16  NUSA TENGGARA BARAT  LOMBOK TIMUR                     SWASTA
# 1 2021-03-30     SULAWESI SELATAN          LUWU  PEMERINTAH KABUPATEN/KOTA
# 2 2021-10-14           JAWA BARAT       BANDUNG  PEMERINTAH KABUPATEN/KOTA
# 3 2021-03-21          JAWA TENGAH        SRAGEN                     SWASTA
# 4 2021-06-16                 ACEH    ACEH UTARA                     SWASTA
#
# ...

# %%
dm4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1702 entries, 0 to 1701
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PSTV01  1702 non-null   int32
#  1   PSTV02  1702 non-null   int32
#  2   PSTV15  1702 non-null   float32
#  3   PNK02   1702 non-null   object
#  4   PNK03   1702 non-null   datetime64[ns]
#  5   PNK04   1702 non-null   datetime64[ns]
#  6   PNK05   1702 non-null   datetime64[ns]
#  7   PNK06   1702 non-null   category
#  8   PNK07   1702 non-null   category
#  9   PNK08   1702 non-null   category
#  10  PNK09   1702 non-null   category
#  11  PNK10   1702 non-null   category
#  12  PNK11   1702 non-null   category
#  13  PNK12   1702 non-null   category
#  14  PNK13   1702 non-null   category
#  15  PNK13A  1702 non-null   object
#  16  PNK14   1702 non-null   object
#  17  PNK15   1702 non-null   object
#  18  PNK16   1702 non-null   category
#  19  PNK17   1702 non-null   int32
# ...

# %% [markdown]
# **Data Non-Kapitasi**
#
# Data Variabel Kepesertaan dan Kunjungan FKTP Non Kapitasi
#
# - PSTV01 (Nomor Peserta):
#     Nomor identifikasi peserta yang bersifat unik dan telah dideidentifikasi untuk melindungi identitas peserta.
# - PSTV02 (Nomor Keluarga):
#     Nomor yang mengidentifikasi kepala keluarga dalam sampel, berfungsi sebagai penanda keluarga (peserta dalam satu keluarga memiliki nomor kepala keluarga yang sama).
# - PSTV15 (Bobot):
#     Faktor pengali yang menggambarkan jumlah individu dalam populasi yang diwakili oleh individu dalam sampel.
# - PNK02 (ID Kunjungan):
#     Nomor identifikasi unik untuk setiap kunjungan FKTP oleh peserta.
# - PNK03 (Tanggal Kunjungan):
#     Tanggal peserta melakukan kunjungan ke FKTP.
# - PNK04 (Tanggal Tindakan):
#     Tanggal dilakukannya tindakan medis.
# - PNK05 (Tanggal Pulang):
#     Tanggal peserta menyelesaikan kunjungan di FKTP.
# - PNK06 (Provinsi Faskes):
#     Provinsi tempat peserta mengakses fasilitas kesehatan tingkat pertama (FKTP).
# - PNK07 (Kode Kab/Kota Faskes):
#     Kabupaten/Kota tempat peserta mengakses FKTP.
# - PNK08 (Kepemilikan Faskes):
#     Kepemilikan fasilitas kesehatan tingkat pertama (FKTP) tempat peserta berkunjung.
# - PNK09 (Jenis Faskes):
#     Jenis fasilitas kesehatan tingkat pertama (FKTP) yang diakses peserta.
# - PNK10 (Tipe Faskes):
#     Tipe fasilitas kesehatan tingkat pertama (FKTP) yang diakses peserta.
# - PNK11 (Tingkat Layanan):
#     Tingkat layanan yang diterima peserta di FKTP.
# - PNK12 (Segmen Peserta):
#     Segmen peserta saat mengakses FKTP.
# - PNK13 (Kode dan Nama Diagnosis - ICD-10 - 3 Digit):
#     Kode dan nama diagnosis berdasarkan 3 digit pertama kode ICD-10 yang diinput ke sistem BPJS Kesehatan.
# - PNK13A (Kode Diagnosis - ICD-10 - 3 Digit):
#     Kode diagnosis berdasarkan 3 digit pertama ICD-10.
# - PNK14 (Kode Diagnosis - 3-5 Digit):
#     Kode diagnosis menurut ICD-10 (dengan jumlah digit antara 3-5).
# - PNK15 (Nama Diagnosis):
#     Nama diagnosis yang terbaca dari sistem BPJS berdasarkan kode yang diinput.
# - PNK16 (Nama Tindakan):
#     Nama jenis tindakan medis yang dilakukan kepada pasien.
# - PNK17 (Biaya Tagih):
#     Biaya yang ditagihkan oleh fasilitas kesehatan untuk setiap ID kunjungan.
# - PNK18 (Biaya Verifikasi):
#     Biaya yang diverifikasi oleh BPJS Kesehatan untuk setiap ID kunjungan.
# - PNK19 (Hasil Pemeriksaan GDP 1):
#     Hasil pemeriksaan gula darah puasa pertama.
# - PNK20 (Hasil Pemeriksaan GDP 2):
#     Hasil pemeriksaan gula darah puasa kedua.

# %% [markdown]
# ### 4. Dataset FKRTL

# %%
import pandas as pd

# Baca file .dta
file_path = "../Dataset/Kontekstual DM/DM2021_fkrtl.dta"  
dm5 = pd.read_stata(file_path)

# Menampilkan beberapa baris pertama dari dataset
dm5.head()
# Out:
#       PSTV01     PSTV02     PSTV15 FKP02             FKL02      FKL03  \
# 0   50886719   50886719  12.507828        414390221V002006 2021-02-20
# 1   70972186    6871133  13.055749        380700421V000216 2021-04-07
# 2   31874094   71865092   7.740489        385450421V006571 2021-04-19
# 3   87945875   87945875   7.734398        206900221V006045 2021-02-28
# 4  384677503  384677503   2.777775        447120121V000468 2021-01-29
#
#        FKL04             FKL05            FKL06                FKL07  ...  \
# 0 2021-02-20              RIAU   KOTA PEKANBARU                POLRI  ...
# 1 2021-04-08  KALIMANTAN TIMUR   KOTA SAMARINDA               TNI AD  ...
# 2 2021-04-19       JAWA TENGAH   KOTA SURAKARTA               Swasta  ...
# 3 2021-03-03              ACEH      ACEH TENGAH  Pemerintah kab/kota  ...
# 4 2021-02-01  SUMATERA SELATAN  KOTA PRABUMULIH               Swasta  ...
#
#   FKL39 FKL40 FKL41 FKL42 FKL43 FKL44 FKL45 FKL46    FKL47    FKL48
# ...

# %%
dm5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826641 entries, 0 to 826640
# Data columns (total 55 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   PSTV01  826641 non-null  int32
#  1   PSTV02  826641 non-null  int32
#  2   PSTV15  826641 non-null  float32
#  3   FKP02   826641 non-null  object
#  4   FKL02   826641 non-null  object
#  5   FKL03   826641 non-null  datetime64[ns]
#  6   FKL04   826641 non-null  datetime64[ns]
#  7   FKL05   826641 non-null  category
#  8   FKL06   826641 non-null  category
#  9   FKL07   826641 non-null  category
#  10  FKL08   826641 non-null  category
#  11  FKL09   826641 non-null  category
#  12  FKL10   826641 non-null  category
#  13  FKL11   826641 non-null  category
#  14  FKL12   826641 non-null  category
#  15  FKL13   826641 non-null  category
#  16  FKL14   826641 non-null  category
#  17  FKL15   826641 non-null  category
#  18  FKL15A  826641 non-null  object
# ...

# %% [markdown]
# **Dataset Kunjungan Peserta**
#
# - PSTV01: Nomor peserta, identifikasi unik peserta yang telah dideidentifikasi untuk melindungi identitas peserta sebenarnya.
# - PSTV02: Nomor keluarga, identifikasi kepala keluarga dalam sampel (peserta dalam keluarga memiliki nomor kepala keluarga yang sama).
# - PSTV15: Bobot, faktor pengali yang mewakili jumlah individu dalam populasi melalui sampel.
# - FKP02: ID kunjungan FKTP, ID kunjungan untuk menggabungkan data pelayanan FKTP dan FKRTL.
# - FKL02: ID kunjungan FKRTL, identifikasi unik untuk kunjungan ke FKRTL.
# - FKL03: Tanggal datang kunjungan FKRTL, tanggal kunjungan dimulai.
# - FKL04: Tanggal pulang kunjungan FKRTL, tanggal kunjungan selesai.
# - FKL05: Provinsi FKRTL, lokasi provinsi fasilitas kesehatan FKRTL.
# - FKL06: Kabupaten/Kota FKRTL, lokasi kabupaten/kota fasilitas kesehatan FKRTL.
# - FKL07: Kepemilikan FKRTL, jenis kepemilikan fasilitas FKRTL.
# - FKL08: Jenis FKRTL, jenis fasilitas kesehatan rujukan tingkat lanjut.
# - FKL09: Tipe FKRTL, tipe fasilitas kesehatan rujukan tingkat lanjut.
# - FKL10: Tingkat pelayanan FKRTL, tingkat layanan di fasilitas FKRTL.
# - FKL11: Jenis Poli FKRTL, poli tempat kunjungan di FKRTL.
# - FKL12: Segmen peserta saat akses layanan FKRTL, segmen peserta saat menggunakan pelayanan di FKRTL.
# - FKL13: Kelas rawat peserta, kelas rawat saat peserta mendapatkan pelayanan FKRTL.
# - FKL14: Status pulang dari FKRTL, status kepulangan peserta setelah pelayanan selesai.
# - FKL15: Kode dan nama diagnosis masuk ICD 10 (3 digit), diagnosis awal berdasarkan ICD 10 (3 digit pertama).
# - FKL15A: Kode diagnosis masuk ICD 10 (3 digit).
# - FKL16: Kode ICD 10 diagnosis masuk FKRTL (3-6 digit), diagnosis awal pada aplikasi INA-CBGs dengan panjang digit variabel.
# - FKL16A: Nama diagnosis masuk FKRTL (3-6 digit), nama diagnosis sesuai kode pada aplikasi INA-CBGs.
# - FKL17: Kode dan nama diagnosis primer ICD 10 (3 digit), diagnosis primer berdasarkan ICD 10 (3 digit pertama).
# - FKL17A: Kode diagnosis primer ICD 10 (3 digit).
# - FKL18: Kode ICD 10 diagnosis primer FKRTL (3-6 digit), diagnosis utama pada hari terakhir perawatan.
# - FKL18A: Nama diagnosis primer FKRTL (3-6 digit), nama diagnosis primer berdasarkan kode diagnosis INA-CBGs.
# - FKL19: Kode INACBGs, kodifikasi diagnosis dan tindakan berdasarkan ICD-10 dan ICD-9.
# - FKL19A: Deskripsi kode INACBGs, nama diagnosis akhir berdasarkan sistem INACBGs.
# - FKL20: INACBGs - Kode Casemix main groups (Digit ke-1), klasifikasi pertama berdasarkan sistem organ.
# - FKL21: INACBGs - Tipe kelompok kasus atau case groups (Digit ke-2).
# - FKL22: INACBGs - Spesifikasi kelompok kasus (Digit ke-3), sub-grup spesifik CBGs dilambangkan dengan numerik 01-99.
# - FKL23: INACBGs - Tingkat keparahan kelompok kasus (Digit ke-4), tingkat keparahan dipengaruhi komorbiditas/komplikasi.
# - FKL25: Provinsi faskes perujuk, lokasi provinsi fasilitas kesehatan pemberi rujukan.
# - FKL26: Kabupaten/Kota faskes perujuk, lokasi kabupaten/kota fasilitas pemberi rujukan.
# - FKL27: Kepemilikan faskes perujuk, kepemilikan fasilitas kesehatan pemberi rujukan.
# - FKL28: Jenis faskes perujuk, jenis fasilitas pemberi rujukan.
# - FKL29: Tipe faskes perujuk, tipe fasilitas kesehatan pemberi rujukan.
# - FKL30: Jenis prosedur, prosedur dilakukan pada pelayanan FKRTL.
# - FKL31: Tarif regional INACBGs, tarif berdasarkan regionalisasi IHK.
# - FKL32: Group Tarif INACBGs, grup tarif paket yang mencakup seluruh komponen rumah sakit.
# - FKL33: Kode special sub-acute groups (SA).
# - FKL34 - Tarif special sub-acute groups (SA) : Tarif yang diberikan untuk special sub-acute groups
# - FKL35 - Kode special procedures (SP): Kode untuk special procedures.
# - FKL36 - Deskripsi special procedures (SP): Penjelasan atau deskripsi dari special procedures.
# - FKL37 - Tarif special procedures (SP): Tarif yang dikenakan untuk special procedures.
# - FKL38 - Kode special prosthesis (RR): Kode untuk special prosthesis
# - FKL39 - Deskripsi special prosthesis (RR): Penjelasan atau deskripsi dari special prosthesis.
# - FKL40 - Tarif special prosthesis (RR): Tarif yang dikenakan untuk special prosthesis.
# - FKL41 - Kode special investigation (SI): Kode untuk special investigation.
# - FKL42 - Deskripsi special investigation (SI): Penjelasan atau deskripsi dari special investigation.
# - FKL43 - Tarif special investigation (SI): Tarif yang dikenakan untuk special investigation.
# - FKL44 - Kode special drugs (SD): Kode untuk special drugs.
# - FKL45 - Deskripsi special drugs (SD): Penjelasan atau deskripsi dari special drugs.
# - FKL46 - Tarif special drugs (SD): Tarif yang dikenakan untuk special drugs.
# - FKL47 - Biaya Tagih oleh fasilitas kesehatan (provider): Biaya yang ditagihkan untuk setiap ID kunjungan, dihitung dari penjumlahan FKL33 + FKL35 + FKL38 + FKL41 + FKL44 + FKL47.
# - FKL48 - Biaya Verifikasi BPJS Kesehatan: Biaya yang telah diverifikasi oleh BPJS Kesehatan untuk setiap ID kunjungan.

# %% [markdown]
# ### 5. Dataset FKRTLD Sekunder

# %%
import pandas as pd

# Baca file .dta
file_path = "../Dataset/Kontekstual DM/DM2021_fkrtldxsekunder.dta"  # Ganti dengan path file Anda
dm6 = pd.read_stata(file_path)

# Menampilkan beberapa baris pertama dari dataset
dm6.head()
# Out:
#               FKL02 FKL24 FKL24A                                   FKL24B
# 0  100080121V000024  E119    E11             E11 Type 2 diabetes mellitus
# 1  100080121V000024   I10    I10     I10 Essential (primary) hypertension
# 2  100080121V000024  I693    I69  I69 Sequelae of cerebrovascular disease
# 3  100080121V000078  E119    E11             E11 Type 2 diabetes mellitus
# 4  100080121V000078  I693    I69  I69 Sequelae of cerebrovascular disease

# %%
dm6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1202910 entries, 0 to 1202909
# Data columns (total 4 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   FKL02   1202910 non-null  object
#  1   FKL24   1202910 non-null  object
#  2   FKL24A  1202910 non-null  object
#  3   FKL24B  1202910 non-null  object
# dtypes: object(4)
# memory usage: 36.7+ MB

# %% [markdown]
# **Data Informasi Diagnosis**
#
# - FKL02 :  ID kunjungan - Nomor identifikasi unik untuk menandakan setiap kunjungan ke FKRTL oleh peserta.
# - FKL24: Kode diagnosis (beragam 3-5 digit) - Kode diagnosis menurut ICD 10 (jumlah digit tidak sama pada semua observasi dengan rentang 3-5 digit kode ICD 10).
# - FKL24A: Kode diagnosis ICD 10 (3 digit) - Kode dan nama diagnosis berdasarkan 3 digit pertama kode ICD 10 yang diperoleh dari hasil input sistem informasi BPJS Kesehatan.
# - FKL24B: Kode dan nama diagnosis ICD 10 (3 digit) - Kode dan nama diagnosis berdasarkan 3 digit pertama kode ICD 10 yang diperoleh dari hasil input sistem informasi BPJS Kesehatan.

# %% [markdown]
# ### 6. Metadata FKTP BPJS

# %%
pip install openpyxl
# Out:
# ...
#
# ...

# %%
# Path
file_path = "../Dataset/Kontekstual DM/Metadata Sampel BPJS.xlsx"

# 1. Baca sheet '2. FKTP' untuk mendapatkan data mapping
fktp = pd.read_excel(file_path, sheet_name="FKTP")
fkp11 = pd.read_excel(file_path, sheet_name="FKP11")
fkp13 = pd.read_excel(file_path, sheet_name="FKP13")
fkp14a = pd.read_excel(file_path, sheet_name="FKP14A")
fkp16 = pd.read_excel(file_path, sheet_name="FKP16")
fkp18 = pd.read_excel(file_path, sheet_name="FKP18")
fkp19 = pd.read_excel(file_path, sheet_name="FKP19")
fkp20 = pd.read_excel(file_path, sheet_name="FKP20")
fkp21 = pd.read_excel(file_path, sheet_name="FKP21")
fkp22 = pd.read_excel(file_path, sheet_name="FKP22")

# %%
fktp
# Out:
#    Variable Information Unnamed: 1  \
# 0              Variable   Position
# 1                PSTV01          1
# 2                PSTV02          2
# 3                PSTV15          3
# 4                 FKP02          4
# 5                 FKP03          5
# 6                 FKP04          6
# 7                 FKP05          7
# 8                 FKP06          8
# 9                 FKP07          9
# 10                FKP08         10
# 11                FKP09         11
# 12                FKP10         12
# 13                FKP11         13
# 14                FKP12         14
# 15                FKP13         15
# 16                FKP14         16
# 17               FKP14A         17
# 18                FKP15         18
# 19               FKP15A         19
# 20                FKP16         20
# 21                FKP17         21
# 22                FKP18         22
# 23                FKP19         23
# 24                FKP20         24
# ...

# %%
fkp11.head()
# Out:
#    FKP11       FKP11_Detail
# 0      1          POLI UMUM
# 1      2  POLI GIGI & MULUT
# 2      3           POLI KIA
# 3      4                UGD
# 4      5            POLI KB

# %%
fkp13
# Out:
#    FKP13      FKP13_Detail
# 0      1     Berobat jalan
# 1      2      Rujuk lanjut
# 2      3            Sembuh
# 3      4    Rujuk internal
# 4      5      Pulang paksa
# 5      6         Lain-lain
# 6      7         Meninggal
# 7     99           Missing
# 8     98  Kunjungan sehat

# %%
fkp14a.head()
# Out:
#   FKP14A                                 ICD10_Text
# 0    A00                                A00 Cholera
# 1    A01         A01 Typhoid and paratyphoid fevers
# 2    A02            A02 Other salmonella infections
# 3    A03                            A03 Shigellosis
# 4    A04  A04 Other bacterial intestinal infections

# %%
fkp16.head()
# Out:
#    FKP16    FKP16_Detail
# 0     11            Aceh
# 1     12  Sumatera Utara
# 2     13  Sumatera Barat
# 3     14            Riau
# 4     15           Jambi

# %%
fkp18
# Out:
#     FKP18               FKP18_Detail
# 0       1             Vertikal/pusat
# 1       2        Pemerintah provinsi
# 2       3  Pemerintah kabupaten/kota
# 3       4                      Polri
# 4       5                     TNI AD
# 5       6                     TNI AL
# 6       7                     TNI AU
# 7       8                       BUMN
# 8       9                     Swasta
# 9      98              Tidak dirujuk
# 10     99                   Missing

# %%
fkp19
# Out:
#    FKP19    FKP19_Detail
# 0      1       Puskesmas
# 1      2  Klinik Pratama
# 2      3     Dokter Umum
# 3     98   Tidak dirujuk
# 4     99        Missing

# %%
fkp20.head()
# Out:
#    FKP20               FKP20_Detail
# 0      1              Apotik Kronis
# 1      2      Apotik PRB dan Kronis
# 2      3                Dokter Gigi
# 3      4  Dokter Prakter Perorangan
# 4      5               Khusus Bedah

# %%
fkp21.head()
# Out:
#    FKP21     FKP21_Detail
# 0      1  AKUPUNTUR MEDIK
# 1      2             ANAK
# 2      3         Anuscopy
# 3      4           APOTIK
# 4      5              ASM

# %%
fkp22
# Out:
#    FKP22      FKP22_Detail
# 0      1   Kunjungan sakit
# 1      2  Kunjungan sehat

# %% [markdown]
# Metadata FKTP BPJS adalah kumpulan informasi yang mendetail mengenai beberapa atribut-atribut categorical yang dikodekan dalam dataset FKTP Kapitasi. Setiap atribut menyimpan informasi penting untuk analisis dan pengelolaan data jaminan kesehatan. Berikut adalah penjelasan untuk beberapa atribut kategorikal tersebut:
#
# FKP05 (Kode Provinsi): Atribut ini menyimpan kode yang digunakan untuk mengidentifikasi provinsi tempat tinggal pasien
# FKP11 (Kode Poliklinik): Kolom ini mencatat kode unik yang mewakili poliklinik atau jenis layanan medis yang ada di fasilitas kesehatan
# FKP13 (Kode Status Kunjungan Pasien): Atribut ini mencatat status kunjungan pasien seperti kunjungan bersifat rawat inap atau rawat jalan dan sebagainya.
# FKP14A (Detail Diagnosis Pasien): Kolom ini menyimpan informasi mengenai diagnosis medis pasien, yaitu kondisi atau penyakit yang terdiagnosis.
# FKP22 (Jenis Kunjungan Pasien-Sehat/Sakit): Atribut ini menjelaskan apakah kunjungan pasien terkait kondisi sakit atau untuk pemeriksaan rutin (sehat).

# %% [markdown]
# ## Main Dataset (Primary Data)

# %% [markdown]
# ### Merge Dataset FKTP With Metadata

# %%
df = dm3

# %%
df = df.merge(fkp11, on="FKP11", how="left")
df = df.merge(fkp13, on="FKP13", how="left")
df = df.merge(fkp14a, on="FKP14A", how="left")
df = df.merge(fkp16, on="FKP16", how="left")
df = df.merge(fkp18, on="FKP18", how="left")
df = df.merge(fkp19, on="FKP19", how="left")
df = df.merge(fkp20, on="FKP20", how="left")
df = df.merge(fkp21, on="FKP21", how="left")
df = df.merge(fkp22, on="FKP22", how="left")

# %%
df.sample(5)
# Out:
#            PSTV01    PSTV02     PSTV15             FKP02      FKP03  \
# 1102783  36562590   7958269   1.363840  291361121P000250 2021-11-27
# 136604   49575924  49575924  12.736865        1487731533 2021-03-23
# 784859   70714459  70714459  12.138740  219140521P000034 2021-05-04
# 28142    56278618  56278618   9.551320        1572539199 2021-06-25
# 353179   84657417  84657417  11.456682  306210621P003013 2021-06-26
#
#              FKP04  FKP05  FKP06  FKP07  FKP08  ...  FKP22  FKP11_Detail  \
# 1102783 2021-11-27     53   5316      3      1  ...      1     POLI UMUM
# 136604  2021-03-23     12   1275      3      1  ...      2           NaN
# 784859  2021-05-04     51   5108      3      1  ...      1     POLI UMUM
# 28142   2021-06-25     73   7309      3      1  ...      2     Konseling
# 353179  2021-06-26     13   1371      3      1  ...      1  LABORATORIUM
#
#              FKP13_Detail                                         ICD10_Text  \
# ...

# %% [markdown]
# Proyek ini berfokus pada dataset FKTP kapitasi. Seusai dengan bussines understanding yang ditetapkan, penelitian ini mengarah pada prediksi kunjungan sakit ataupun sehat pada pasien. Dataset FKTP kapitasi memuat beberapa atribut yang dapat membantu peneliti dalam mengklasifikasikan jenis kunjungan. Disamping mengklasifikasikan pasien berdasarkan jenis kunjungannya apakah sakit atau sehat, penelitian ini juga bertujuan untuk memfokuskan klasifikasi lebih dalam lagi pada jenis kunjungan yang tergolong sakit. Salah satu atribut dalam dataset FKTP Kapitasi yaitu atribut "status kunjungan kerja (FKP13)" memiliki potensi untuk dijadikan label dalam pemodelan nantinya. Kemudian dataset lainnya seperti dapat dilihat pada code diatas dimana peneliti melakukan merge antar tabel, maka atribut baru tersebut akan menjadi data pendukung dalam memudahkan dan menambahkan informasi penting yang mendukung penyampaian informasi hasil prediksi dengan lebih baik pada saat implementasi hasil.

# %% [markdown]
# ### Dataset Overview

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
# Menghapus kolom dengan tipe data datetime
df = df.drop(columns=df.select_dtypes(include=['datetime64[ns]']).columns)

# %%
# Memisahkan kolom numerical dan categorical
int_columns = df.select_dtypes(include=['int8', 'int16', 'int32', 'int64', 'float32', 'float64']).columns
obj_columns = df.select_dtypes(include=['object']).columns

# %%
df.shape
# Out:
# (1193164, 33)

# %% [markdown]
# Kode di atas bertujuan untuk memberikan gambaran awal dari dataset dengan beberapa langkah preprocessing. Pertama, library seperti NumPy, Matplotlib, dan Seaborn diimpor untuk analisis dan visualisasi data. Lalu, kolom dengan tipe data datetime dihapus dari dataset menggunakan fungsi df.drop. Setelah itu, kolom-kolom dataset dipisahkan menjadi dua kelompok berdasarkan tipe datanya: kolom seperti integer dan float disimpan dalam int_columns, sedangkan kolom string dengan tipe data objek disimpan dalam obj_columns. Terakhir, ukuran dataset (jumlah baris dan kolom) ditampilkan menggunakan df.shape. Langkah ini mempersiapkan dataset untuk analisis lebih lanjut dengan memisahkan tipe data dan menyederhanakan struktur dataset.

# %% [markdown]
# ### Integer Atribute Overview

# %% [markdown]
# #### 1. Integer Statistical Analysis

# %%
df[int_columns].describe()
# Out:
#              PSTV01        PSTV02        PSTV15         FKP05         FKP06  \
# count  1.193164e+06  1.193164e+06  1.193164e+06  1.193164e+06  1.193164e+06
# mean   8.963077e+07  1.074483e+08  1.063188e+01  3.537838e+01  3.576196e+03
# std    1.093041e+08  1.261364e+08  3.237194e+00  1.752065e+01  1.749937e+03
# min    9.680000e+02  5.170000e+02  7.004679e-01  1.100000e+01  1.101000e+03
# 25%    2.849620e+07  3.060743e+07  9.322668e+00  3.100000e+01  3.172000e+03
# 50%    5.693146e+07  6.116768e+07  1.186822e+01  3.300000e+01  3.321000e+03
# 75%    8.598844e+07  9.192822e+07  1.291479e+01  3.500000e+01  3.578000e+03
# max    4.553888e+08  4.553888e+08  3.829594e+01  9.400000e+01  9.471000e+03
#
#               FKP07         FKP08         FKP09         FKP10         FKP11  \
# count  1.193164e+06  1.193164e+06  1.193164e+06  1.193164e+06  1.193164e+06
# mean   5.570314e+00  1.714661e+00  2.923789e+00  1.275437e+00  4.786126e+00
# ...

# %% [markdown]
# Kode ini menggunakan describe() untuk menampilkan statistik deskriptif kolom numerik, seperti jumlah data, rata-rata, standar deviasi, nilai minimum, kuartil (25%, 50%, 75%), dan nilai maksimum. Hasilnya memberikan gambaran distribusi dan karakteristik data numerik.

# %% [markdown]
# #### 2. Data Integer Headmap Visualization

# %%
# Hitung korelasi antar kolom
correlation_matrix = df[int_columns].corr()

# Plot heatmap
plt.figure(figsize=(15, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %% [markdown]
# Kode ini digunakan untuk menghitung dan memvisualisasikan matriks korelasi antar kolombetipe angka dalam dataset. Pertama, fungsi .corr() diterapkan pada int_columns untuk menghitung korelasi antar kolom, yang hasilnya disimpan dalam correlation_matrix. Kemudian, fungsi sns.heatmap dari Seaborn digunakan untuk membuat heatmap korelasi dengan anotasi nilai korelasi, palet warna 'coolwarm', dan format angka dua desimal. Ukuran gambar diatur dengan figsize=(10, 8), dan judul heatmap ditambahkan dengan plt.title. Visualisasi ini membantu mengidentifikasi hubungan linier antar kolom secara cepat.
#
# Berdasarkan heatmap korelasi yang ditampilkan, hubungan antar atribut yang memiliki nilai korelasi lebih besar dari 0.89 (ditandai dengan warna merah gelap) adalah sebagai berikut:
# - FKP16 dan FKP17 (korelasi ≈ 1.00)
# - FKP16 dan FKP18 (korelasi ≈ 0.96)
# - FKP16 dan FKP19 (korelasi ≈ 0.96)
# - FKP16 dan FKP20 (korelasi ≈ 0.96)
# - FKP16 dan FKP21 (korelasi ≈ 0.89)
# - FKP05 dan FKP06 (korelasi ≈ 1.00)
# - FKP06 dan FKP05 (korelasi ≈ 1.00)
# - FKP13 dan FKP14 (korelasi ≈ 1.00)
# - FKP14 dan FKP13 (korelasi ≈ 1.00)
# - FKP13 dan FKP22 (korelasi ≈ 1.00)
# - FKP14 dan FKP22 (korelasi ≈ 1.00)
# - FKP17 dan FKP16 (korelasi ≈ 1.00)
# - FKP17 dan FKP18 (korelasi ≈ 0.96)
# - FKP17 dan FKP19 (korelasi ≈ 0.96)
# - FKP17 dan FKP20 (korelasi ≈ 0.96)
# - FKP17 dan FKP21 (korelasi ≈ 0.89)
# - FKP18 dan FKP16 (korelasi ≈ 0.96)
# - FKP18 dan FKP17 (korelasi ≈ 0.96)
# - FKP18 dan FKP19 (korelasi ≈ 1.00)
# - FKP18 dan FKP20 (korelasi ≈ 1.00)
#
# Atribut-atribut ini menunjukkan hubungan sangat kuat (korelasi tinggi), yang mungkin mengindikasikan redundansi dalam data dan perlu dipertimbangkan untuk analisis atau feature selection.
#
# Dikarenakan fokus proyek ini berkaitan dengan klasifikasi kunjungan sehat atau sakit maka korelasi yang berhubungan dengan atribut FKP13 lebih difokuskan. Atribut-atribut yang setidaknya memiliki korelasi diatas 0.1 dengan FKP13 akan digunakan sebagai feature untuk melatih model. Adapun atribut tersebut diantaranya adalah FKP11, FKP14, FKP16, FKP18, FKP19, FKP20, FKP21, dan FKP22. Dalam pemilihan ini FKP17 tidak diikut sertakan karena atribut memberikan informasi yang menyimpan data yang banyak dan panjang pada pengolahan data kedepannya.

# %% [markdown]
# #### 3. Data Integer Histogram Visualization

# %%
import math

num_columns = len(int_columns)

# Tentukan ukuran layout berdasarkan jumlah kolom 
rows = math.ceil(num_columns / 4)
cols = 4

# Plot histogram
df[int_columns].hist(
    edgecolor='black', 
    bins=15, 
    figsize=(cols * 6, rows * 5),
    layout=(rows, cols)
)
# Out:
# array([[<Axes: title={'center': 'PSTV01'}>,
#         <Axes: title={'center': 'PSTV02'}>,
#         <Axes: title={'center': 'PSTV15'}>,
#         <Axes: title={'center': 'FKP05'}>],
#        [<Axes: title={'center': 'FKP06'}>,
#         <Axes: title={'center': 'FKP07'}>,
#         <Axes: title={'center': 'FKP08'}>,
#         <Axes: title={'center': 'FKP09'}>],
#        [<Axes: title={'center': 'FKP10'}>,
#         <Axes: title={'center': 'FKP11'}>,
#         <Axes: title={'center': 'FKP12'}>,
#         <Axes: title={'center': 'FKP13'}>],
#        [<Axes: title={'center': 'FKP14'}>,
#         <Axes: title={'center': 'FKP16'}>,
#         <Axes: title={'center': 'FKP17'}>,
#         <Axes: title={'center': 'FKP18'}>],
#        [<Axes: title={'center': 'FKP19'}>,
#         <Axes: title={'center': 'FKP20'}>,
#         <Axes: title={'center': 'FKP21'}>,
#         <Axes: title={'center': 'FKP22'}>]], dtype=object)

# %% [markdown]
# Kode ini bertujuan untuk membuat histogram distribusi data dari setiap kolom numerik dalam dataset. Pertama, jumlah kolom numerik dihitung dengan len(numerical_columns). Selanjutnya, layout grid ditentukan berdasarkan jumlah kolom, diatur menjadi 4 kolom per baris dengan jumlah baris yang dihitung menggunakan math.ceil. Fungsi df[numerical_columns].hist() kemudian digunakan untuk menghasilkan histogram setiap kolom numerik dengan parameter seperti bins (jumlah interval histogram), edgecolor (warna tepi), dan figsize untuk mengatur ukuran keseluruhan plot. Layout ditentukan oleh jumlah baris dan kolom yang sudah diatur sebelumnya.
#
# Penjelasan grafik output: Setiap histogram menggambarkan distribusi data untuk kolom numerik yang berbeda. Sebagian besar kolom menunjukkan distribusi yang tidak merata, dengan data yang cenderung terkonsentrasi pada nilai tertentu (seperti distribusi skewed). Misalnya, kolom seperti FKP16, FKP17, dan FKP18 menunjukkan data yang sangat terpusat di satu nilai, mengindikasikan distribusi yang kurang variatif. Visualisasi ini membantu dalam memahami pola data dan potensi outlier atau nilai dominan dalam setiap atribut numerik.

# %% [markdown]
# #### 4. Data Integer Boxplot Visualization

# %%
# Jumlah baris dan kolom yang dibutuhkan
cols = 4
rows = math.ceil(len(int_columns) / cols)

plt.figure(figsize=(cols * 4, rows * 3))  # Sesuaikan ukuran figure

for i, col in enumerate(int_columns, start=1):
    plt.subplot(rows, cols, i)
    df.boxplot(column=col)
    plt.title(f'Boxplot of {col}')
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Kode ini bertujuan untuk membuat diagram boxplot dari setap  data di atribut integer, dengan tujuan menganalisis pola distribusi serta variatif data dan memahami kemungkinan outlier pada data. Dari hasil visualisasi boxplot yang ditemukan, diperoleh bahwa atribut-atribut numerik ini dapat dikategorikan menjadi beberapa bagian :
# 1. Tidak memiliki outlier : FKPO7, FKP12
# 2. Memiliki sedikit outlier (jarak outlier dekat) : FKP08, FKPO9, FKP10,
# 3. Memiliki sedikit outlier (jarak outlier jauh) : FKP13, FKP14, FKP18, FKP19, FKP22
# 4. Memiliki banyak outlier : PSTV01, PSTV02, PSTV15, FKPO5, FKPO6, FKP11, FKP16, FKP17, FKP20, FKP21
#
# Disamping digunakan untuk mengindentifikasi potensi outlier diatas, boxplot ini juga digunakan untuk mengetahui atribut integer yang bersifat kategorikal. Jika terdapat banyak data yang diluar rentang distribusi data normal, dapat disimpulkan bahwa data-data yang tersimpan dalam atribut tersebut bervariasi antara data mayoritas yang juga memiliki banyak data minoritas

# %% [markdown]
# ### Object Atribute Overview

# %% [markdown]
# #### 1. Data Object Uniqe Count Analysis

# %%
# Menampilkan nilai unik untuk setiap kolom kategorikal
for col in obj_columns:
    unique_values = df[col].unique()
    print(f"Kolom: {col}")
    print(f"Jumlah nilai unik: {len(unique_values)}")
    print(f"Nilai unik: {unique_values}")
    print("-" * 50)
# Out:
# Kolom: FKP02
# Jumlah nilai unik: 1188324
# Nilai unik: ['1687160334' '1457720536' '1732989007' ... '342530321P000054'
#  '342530221P000002' '243990921P000026']
# --------------------------------------------------
# Kolom: FKP14A
# Jumlah nilai unik: 1411
# Nilai unik: ['' 'A00' 'A01' ... 'Z97' 'Z98' 'Z99']
# --------------------------------------------------
# Kolom: FKP15
# Jumlah nilai unik: 5170
# Nilai unik: ['9999' 'A00' 'A000' ... 'Z992' 'Z999' 'Z998']
# --------------------------------------------------
# Kolom: FKP15A
# Jumlah nilai unik: 5169
# Nilai unik: ['9999' 'Cholera' 'Cholera due to Vibrio cholerae 01, biovar cholerae' ...
#  'Dependence on renal dialysis'
#  'Dependence on unspecified enabling machine and device'
#  'Dependence on other enabling machines and devices']
# --------------------------------------------------
# Kolom: FKP11_Detail
# Jumlah nilai unik: 22
# Nilai unik: ['Konseling' 'Home-Visit' 'Imunisasi (BCG)' nan 'POLI UMUM'
# ...

# %% [markdown]
# Kode ini bertujuan untuk menampilkan nilai unik dari setiap kolom object dalam dataset. Dengan menggunakan perulangan for, setiap kolom dalam obj_columns diakses, kemudian nilai uniknya dihitung menggunakan fungsi unique() dan panjang daftar nilai unik dihitung dengan len(). Untuk setiap kolom, nama kolom, jumlah nilai unik, dan daftar nilai unik ditampilkan. Selain itu, garis pemisah dicetak untuk memudahkan membaca output.
#
# Penjelasan output:
#
# - Kolom FKP02 memiliki jumlah nilai unik yang sangat besar (1.188.324), dengan contoh nilai unik seperti kode angka besar.
# - Kolom FKP14A memiliki 1.411 nilai unik dengan nilai berupa kode seperti A00, A01, hingga Z99.
# - Kolom FKP15 memiliki 5.170 nilai unik, menunjukkan variasi yang lebih besar.
# - Kolom FKP15A juga memiliki jumlah nilai unik yang mendekati kolom sebelumnya (5.169) dengan nilai berupa deskripsi, seperti dependensi pada alat medis.
# - Kolom FKP05_Detail memiliki 34 nilai unik, yang memuat nama-nama provinsi di Indonesia
# - Kolom FKP11_Detail memiliki 22 nilai unik, yang memuat nama-nama jenis poliklinik dalam fasilitas kesehatan yang disediakan
# - Kolom FKP13_Detail memiliki 7 nilai unik, menunjukkan status kunjungan yang dilakukan oleh pasien setiap kali mengunjungi fasilitas kesehatan
# - Kolom ICD10_Text memiliki 1.411 nilai unik yang sama seperti FKP14A, karena atribut ini menjelaskan lebih detail kode diagnosisnya
# - Kolom FKP22_Detail memiliki 2 nilai unik yaitu kunjungan sehat dan kunjungan sakit

# %% [markdown]
# #### 2. Data Object FKP14A (Kode Diagnosis umum) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada FKP14A
top_values = df['FKP14A'].value_counts().head(20)  # 20 nilai teratas
top_values.plot(kind='bar', figsize=(10, 5), title="Top 20 FKP14A Values")
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Kode ini bertujuan untuk memvisualisasikan 20 nilai teratas dengan frekuensi tertinggi pada kolom FKP14A. Fungsi value_counts() digunakan untuk menghitung jumlah kemunculan setiap nilai, dan head(20) mengambil 20 nilai teratas berdasarkan frekuensinya. Nilai-nilai tersebut diplot dalam grafik batang menggunakan plot(kind='bar'), dengan ukuran gambar diatur melalui figsize, serta ditambahkan judul, label sumbu X sebagai "Value," dan label sumbu Y sebagai "Frequency."
#
# Penjelasan grafik output: Grafik menunjukkan distribusi frekuensi 20 nilai teratas dari kolom FKP14A. Nilai E11 memiliki frekuensi tertinggi dengan lebih dari 400.000 kemunculan, diikuti oleh I10 dan E10 yang masing-masing memiliki frekuensi lebih rendah secara bertahap. Sementara nilai lainnya, seperti I15, K29, dan N18, memiliki frekuensi yang jauh lebih rendah. Visualisasi ini membantu memahami pola dominasi nilai tertentu dalam data kategorikal dan mengidentifikasi potensi nilai-nilai penting atau outlier.

# %% [markdown]
# #### 3. Data Object FKP15 (Kode Diagnosis lanjut) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada FKP15
top_values = df['FKP15'].value_counts().head(20)  # 20 nilai teratas
top_values.plot(kind='bar', figsize=(10, 5), title="Top 20 FKP15 Values")
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Kode ini digunakan untuk memvisualisasikan 20 nilai dengan frekuensi tertinggi pada kolom FKP15. Fungsi value_counts() menghitung jumlah kemunculan setiap nilai dalam kolom tersebut, dan head(20) memilih 20 nilai paling sering muncul. Data ini kemudian diplot dalam grafik batang dengan plot(kind='bar'), di mana ukuran grafik diatur dengan figsize, dan diberi judul "Top 20 FKP15 Values" serta label untuk sumbu X dan Y.
#
# Penjelasan grafik output: Grafik menunjukkan distribusi frekuensi nilai-nilai teratas dalam kolom FKP15. Nilai 9999 memiliki frekuensi tertinggi, diikuti oleh E119, E11, dan I10. Nilai-nilai ini memiliki frekuensi yang menurun secara bertahap. Nilai-nilai lain seperti E116, E149, dan M79.1 memiliki frekuensi yang jauh lebih rendah. Grafik ini memberikan wawasan tentang nilai yang paling dominan dalam kolom FKP15, yang dapat membantu dalam analisis lebih lanjut, seperti mendeteksi dominasi nilai tertentu atau keberadaan nilai outlier.

# %% [markdown]
# #### 4. Data Object FKP15A (Deskripsi Diagnosis lanjut) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada FKP15
top_values = df['FKP15A'].value_counts().head(20)
top_values.plot(kind='barh', figsize=(10, 5), title="Top 20 FKP15A Values")
plt.xlabel('Frequency') 
plt.ylabel('Value')     
plt.show()

# %% [markdown]
# Kode ini digunakan untuk memvisualisasikan 20 nilai teratas yang paling sering muncul pada kolom FKP15A dalam dataset. Dengan menggunakan value_counts() untuk menghitung frekuensi kemunculan setiap nilai, data tersebut diurutkan berdasarkan jumlah frekuensi, dan head(20) memilih 20 nilai teratas. Data ini diplot dalam grafik batang horizontal dengan plot(kind='barh'), ukuran grafik ditentukan oleh figsize, dan diberikan judul "Top 40 FKP15A Values" serta label pada sumbu X dan Y.
#
# Penjelasan grafik output: Grafik menunjukkan distribusi frekuensi dari 20 nilai teratas di kolom FKP15A. Nilai 9999 memiliki frekuensi tertinggi, diikuti oleh deskripsi seperti "Non-insulin-dependent diabetes mellitus without complications" dan "Essential (primary) hypertension". Frekuensi ini menurun pada nilai-nilai berikutnya. Grafik ini memberikan wawasan tentang dominasi beberapa kategori tertentu dalam kolom tersebut, yang dapat membantu dalam analisis lebih lanjut seperti identifikasi nilai-nilai umum atau mendeteksi data yang tidak seimbang.

# %% [markdown]
# #### 5. Data Object FKP11 (Jenis Poliklinik) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada FKP11_Detail
top_values = df['FKP11_Detail'].value_counts().head(20)
top_values.plot(kind='barh', figsize=(10, 5), title="Top 20 FKP11 Values")
plt.xlabel('Frequency') 
plt.ylabel('Value')     
plt.show()

# %% [markdown]
# #### 6. Data Object FKP13 (Status Kunjungan pasien) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada FKP13
top_values = df['FKP13_Detail'].value_counts().head(20)
top_values.plot(kind='barh', figsize=(10, 5), title="Top 20 FKP13 Values")
plt.xlabel('Frequency') 
plt.ylabel('Value')     
plt.show()

# %% [markdown]
# #### 7. Data Object ICD10_Text (Deskripsi Diagnosis umum) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada ICD10_Text
top_values = df['ICD10_Text'].value_counts().head(20)
top_values.plot(kind='barh', figsize=(10, 5), title="Top 20 ICD10_Text Values")
plt.xlabel('Frequency') 
plt.ylabel('Value')     
plt.show()

# %% [markdown]
# #### 8. Data Object FKP16 (Provinsi) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada FKP16_Detail
top_values = df['FKP16_Detail'].value_counts().head(20)
top_values.plot(kind='barh', figsize=(10, 5), title="Top 20 FKP16 Values")
plt.xlabel('Frequency') 
plt.ylabel('Value')     
plt.show()

# %% [markdown]
# #### 9. Data Object FKP18 (Kepemilikan Fasilitas Kesehatan) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada FKP18_Detail
top_values = df['FKP18_Detail'].value_counts().head(20)
top_values.plot(kind='barh', figsize=(10, 5), title="Top 20 FKP18 Values")
plt.xlabel('Frequency') 
plt.ylabel('Value')     
plt.show()

# %% [markdown]
# #### 10. Data Object FKP19 (Jenis Fasilitas Kesehatan) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada FKP19_Detail
top_values = df['FKP19_Detail'].value_counts().head(20)
top_values.plot(kind='barh', figsize=(10, 5), title="Top 20 FKP19 Values")
plt.xlabel('Frequency') 
plt.ylabel('Value')     
plt.show()

# %% [markdown]
# #### 11. Data Object FKP20 (Tipe Fasilitas Kesehatan) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada FKP20_Detail
top_values = df['FKP20_Detail'].value_counts().head(20)
top_values.plot(kind='barh', figsize=(10, 5), title="Top 20 FKP20 Values")
plt.xlabel('Frequency') 
plt.ylabel('Value')     
plt.show()

# %% [markdown]
# #### 12. Data Object FKP21 (Poli Fasilitas Kesehatan) TOP-20 Values Frequency Visualization

# %%
# Frekuensi nilai unik pada FKP21_Detail
top_values = df['FKP21_Detail'].value_counts().head(20)
top_values.plot(kind='barh', figsize=(10, 5), title="Top 20 FKP21 Values")
plt.xlabel('Frequency') 
plt.ylabel('Value')     
plt.show()

# %% [markdown]
# ### Data Understanding Conculusion

# %% [markdown]
# Setelah melakukan data understanding terhadap data utama yang digunakan, maka dengan ini kami memutuskan untuk menggunakan atribut-atribut berikut sebagai feature dan target untuk melatih model dalam mengklasifikasikan prediksi kunjungan sehat atau sakit. Atribut-atribut ini terdiri atas atribut numerik dan categorical yaitu :
# 1. FKP11
# 2. FKP13
# 3. FKP14
# 4. FKP15
# 5. FKP15A
# 6. FKP16
# 7. FKP18
# 8. FKP19
# 9. FKP20
# 10. FKP21
# 11. FKP22
# 12. FKP11_Detail
# 13. FKP13_Detail
# 14. ICD10_Text
# 15. FKP16_Detail
# 16. FKP18_Detail
# 17. FKP19_Detail
# 18. FKP20_Detail
# 19. FKP21_Detail
# 20. FKP22_Detail
#
# Pemilihan atribut-atribut ini berlatarkan berbagai alasan yang diantaranya adalah korelasi tinggi antara atribut dengan atribut target, manfaat atribut dalam memberikan informasi klasifikasi yang lebih detail pada hasil klasifikasi yang dirancang, dan manfaat dari informasi diagnosis yang disimpan oleh atribut. Walaupun demikian, atribut-atribut ini akan diperbaharui dengan menerapkan tahapan preprocessing untuk memastikan data yang clean, tidak noise, tidak outlier, dan terdistribusi dengan baik. Disamping itu akan dilakukan beberapa pengaturan pada isi atribut-atribut tertentu yang disesuaikan dengan informasi dari dataset sekunder. Hal ini bertujuan untuk memaksimalkan informasi yang kaya kedalam atribut sehingga mampu memberikan klasifikasi kunjungan sakit dan sehat yang lebih detail.

# %% [markdown]
# # DATA PREPARATION

# %% [markdown]
# ## Dataset Attribute Selection

# %%
# view dataset before selection
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1193164 entries, 0 to 1193163
# Data columns (total 33 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   PSTV01        1193164 non-null  int32
#  1   PSTV02        1193164 non-null  int32
#  2   PSTV15        1193164 non-null  float32
#  3   FKP02         1193164 non-null  object
#  4   FKP05         1193164 non-null  int8
#  5   FKP06         1193164 non-null  int16
#  6   FKP07         1193164 non-null  int8
#  7   FKP08         1193164 non-null  int8
#  8   FKP09         1193164 non-null  int8
#  9   FKP10         1193164 non-null  int8
#  10  FKP11         1193164 non-null  int8
#  11  FKP12         1193164 non-null  int8
#  12  FKP13         1193164 non-null  int8
#  13  FKP14         1193164 non-null  int16
#  14  FKP14A        1193164 non-null  object
#  15  FKP15         1193164 non-null  object
#  16  FKP15A        1193164 non-null  object
# ...

# %%
# Chosing the relevan columns
selected_columns = ['FKP11', 'FKP13', 'FKP14', 'FKP15','FKP16', 'FKP18', 'FKP19', 'FKP20', 'FKP21','FKP15A', 'FKP22', 'FKP11_Detail', 'FKP13_Detail', 'ICD10_Text','FKP16_Detail', 'FKP18_Detail', 'FKP19_Detail', 'FKP20_Detail', 'FKP21_Detail' ,'FKP22_Detail']
selected_data = df[selected_columns]

# %%
print("Informasi Kolom yang Dipilih:")
print(selected_data.info())
# Out:
# Informasi Kolom yang Dipilih:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1193164 entries, 0 to 1193163
# Data columns (total 20 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   FKP11         1193164 non-null  int8
#  1   FKP13         1193164 non-null  int8
#  2   FKP14         1193164 non-null  int16
#  3   FKP15         1193164 non-null  object
#  4   FKP16         1193164 non-null  int8
#  5   FKP18         1193164 non-null  int8
#  6   FKP19         1193164 non-null  int8
#  7   FKP20         1193164 non-null  int8
#  8   FKP21         1193164 non-null  int16
#  9   FKP15A        1193164 non-null  object
#  10  FKP22         1193164 non-null  int8
#  11  FKP11_Detail  1158750 non-null  object
#  12  FKP13_Detail  1193164 non-null  object
#  13  ICD10_Text    960461 non-null   object
#  14  FKP16_Detail  204342 non-null   object
#  15  FKP18_Detail  1193164 non-null  object
# ...

# %% [markdown]
# ### Dataset Attribute Reconstruction

# %%
# Changing the name of the chosen columns
column_mapping = {
    'FKP11': 'Kode_Jenis_Poliklinik',
    'FKP13': 'Kode_Status_Kunjungan_Peserta',
    'FKP14': 'Kode_Diagnosis',
    'FKP15': 'Kode_Diagnosis_Detail',
    'FKP16': 'Kode_Provinsi_faskes_tujuan_rujukan',
    'FKP18': 'Kode_Kepemilikan_faskes',
    'FKP19': 'Kode_Jenis_faskes',
    'FKP20': 'Kode_Tipe_faskes',
    'FKP21': 'Kode_Poli_faskes',
    'FKP15A': 'Nama_Diagnosis_Detail',
    'FKP22': 'Kode_Jenis_Kunjungan',
    'FKP11_Detail': 'Jenis_Poliklinik',
    'FKP13_Detail': 'Status_Kunjungan_Peserta',
    'ICD10_Text': 'Nama_Diagnosis',
    'FKP16_Detail': 'Provinsi_faskes_tujuan_rujukan',
    'FKP18_Detail': 'Kepemilikan_faskes',
    'FKP19_Detail': 'Jenis_faskes',
    'FKP20_Detail': 'Tipe_faskes',
    'FKP21_Detail': 'Poli_faskes',
    'FKP22_Detail': 'Jenis_Kunjungan',
}
selected_data.rename(columns=column_mapping, inplace=True)
# Out:
# C:\Users\Rebecca YBS\AppData\Local\Temp\ipykernel_24268\296111983.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data.rename(columns=column_mapping, inplace=True)

# %% [markdown]
# ## Dataset Attribute Cleaning

# %%
# Delete data duplicates
selected_data = selected_data.drop_duplicates()
print("Informasi Dataset Setelah Mengganti Nama Kolom:")
print(selected_data.info())
# Out:
# Informasi Dataset Setelah Mengganti Nama Kolom:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53426 entries, 0 to 1193163
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Kode_Jenis_Poliklinik                53426 non-null  int8
#  1   Kode_Status_Kunjungan_Peserta        53426 non-null  int8
#  2   Kode_Diagnosis                       53426 non-null  int16
#  3   Kode_Diagnosis_Detail                53426 non-null  object
#  4   Kode_Provinsi_faskes_tujuan_rujukan  53426 non-null  int8
#  5   Kode_Kepemilikan_faskes              53426 non-null  int8
#  6   Kode_Jenis_faskes                    53426 non-null  int8
#  7   Kode_Tipe_faskes                     53426 non-null  int8
#  8   Kode_Poli_faskes                     53426 non-null  int16
#  9   Nama_Diagnosis_Detail                53426 non-null  object
# ...

# %%
# Mengecek jumlah nilai null pada setiap kolom
missing_values = selected_data.isnull().sum()

# Menampilkan kolom yang memiliki nilai null
print("Kolom dengan nilai null:")
print(missing_values[missing_values > 0])
# Out:
# Kolom dengan nilai null:
# Jenis_Poliklinik                   517
# Nama_Diagnosis                      12
# Provinsi_faskes_tujuan_rujukan    6115
# Tipe_faskes                       6185
# Poli_faskes                          4
# dtype: int64

# %%
# Menghapus baris yang memiliki NaN pada kolom Jenis_Poliklinik
selected_data = selected_data.dropna(subset=['Jenis_Poliklinik'])

# Mengisi NaN pada kolom Nama_Diagnosis dengan nilai 'Tidak Ada'
selected_data[['Nama_Diagnosis','Poli_faskes']] = selected_data[['Nama_Diagnosis','Poli_faskes']].fillna('Tidak Ada')

# Mengisi NaN pada kolom Nama_Diagnosis dengan nilai 'Tidak Dirujuk'
selected_data[['Provinsi_faskes_tujuan_rujukan','Tipe_faskes']] = selected_data[['Provinsi_faskes_tujuan_rujukan','Tipe_faskes']].fillna('Tidak Dirujuk')

# Outputkan hasil untuk memastikan perubahan
print(selected_data.isnull().sum())
# Out:
# Kode_Jenis_Poliklinik                  0
# Kode_Status_Kunjungan_Peserta          0
# Kode_Diagnosis                         0
# Kode_Diagnosis_Detail                  0
# Kode_Provinsi_faskes_tujuan_rujukan    0
# Kode_Kepemilikan_faskes                0
# Kode_Jenis_faskes                      0
# Kode_Tipe_faskes                       0
# Kode_Poli_faskes                       0
# Nama_Diagnosis_Detail                  0
# Kode_Jenis_Kunjungan                   0
# Jenis_Poliklinik                       0
# Status_Kunjungan_Peserta               0
# Nama_Diagnosis                         0
# Provinsi_faskes_tujuan_rujukan         0
# Kepemilikan_faskes                     0
# Jenis_faskes                           0
# Tipe_faskes                            0
# Poli_faskes                            0
# Jenis_Kunjungan                        0
# dtype: int64

# %% [markdown]
# ## Defining Labels for the Dataset

# %%
# Ambil nilai unik dari kolom 'Status_Kunjungan_Peserta'
unique_values = selected_data['Kode_Status_Kunjungan_Peserta'].unique()

# Fungsi untuk menentukan label numerik
def determine_label(label):
    if label == 5 or label == 6 or label == 7:  # Gabungkan Pulang Paksa (5), Lain-lain (6), dan Meninggal (7)
        return 4  # Label baru untuk kategori "Lainnya"
    elif label == 98:  # Kunjungan Sehat tetap dengan label 3
        return 3
    return label - 1  # Mengubah label 1 menjadi 0, 2 menjadi 1, 3 menjadi 2, dst.

# Terapkan fungsi ke kolom 'Label'
selected_data['Label'] = selected_data['Kode_Status_Kunjungan_Peserta'].apply(determine_label)

# Tampilkan distribusi baru dari kolom 'Label' dan 'Status_Kunjungan_Peserta'
print(selected_data[['Label', 'Status_Kunjungan_Peserta', 'Kode_Status_Kunjungan_Peserta']].value_counts())
# Out:
# Label  Status_Kunjungan_Peserta  Kode_Status_Kunjungan_Peserta
# 1      Rujuk lanjut              2                                47311
# 0      Berobat jalan             1                                 5044
# 2      Sembuh                    3                                  390
# 4      Lain-lain                 6                                   90
#        Pulang paksa              5                                   35
#        Meninggal                 7                                   29
# 3      Kunjungan sehat           98                                  10
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

# Mengidentifikasi kelas mayoritas dan minoritas
majority_class_1 = selected_data[selected_data['Label'] == 1]  # Kelas mayoritas 1
minority_classes = selected_data[(selected_data['Label'] != 1) ]  # Semua kelas selain 1 adalah minoritas

# Undersampling kelas mayoritas 1
majority_undersampled_1 = resample(majority_class_1, 
                                   replace=False,   # Tidak ada duplikasi
                                   n_samples=20000,  # Sesuaikan jumlah sampel dengan kelas minoritas
                                   random_state=42)

# Gabungkan kembali kelas mayoritas yang sudah diundersample dengan kelas minoritas
selected_data = pd.concat([majority_undersampled_1, minority_classes])

# Memeriksa distribusi data setelah undersampling
print(selected_data['Label'].value_counts())
# Out:
# Label
# 1    20000
# 0     5044
# 2      390
# 4      154
# 3       10
# Name: count, dtype: int64

# %% [markdown]
# ## Dataset Attribute Integration

# %%
selected_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25598 entries, 294396 to 1193118
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Kode_Jenis_Poliklinik                25598 non-null  int8
#  1   Kode_Status_Kunjungan_Peserta        25598 non-null  int8
#  2   Kode_Diagnosis                       25598 non-null  int16
#  3   Kode_Diagnosis_Detail                25598 non-null  object
#  4   Kode_Provinsi_faskes_tujuan_rujukan  25598 non-null  int8
#  5   Kode_Kepemilikan_faskes              25598 non-null  int8
#  6   Kode_Jenis_faskes                    25598 non-null  int8
#  7   Kode_Tipe_faskes                     25598 non-null  int8
#  8   Kode_Poli_faskes                     25598 non-null  int16
#  9   Nama_Diagnosis_Detail                25598 non-null  object
#  10  Kode_Jenis_Kunjungan                 25598 non-null  int8
# ...

# %%
# Save the final dataset, after preparation

final_output_path = "../Dataset/Kontekstual DM/final_processed_data.csv"  
selected_data.to_csv(final_output_path, index=False)
print(f"Dataset yang telah diproses dan lengkap disimpan ke {final_output_path}.")
# Out:
# Dataset yang telah diproses dan lengkap disimpan ke ../Dataset/Kontekstual DM/final_processed_data.csv.

# %% [markdown]
# # MODELING

# %% [markdown]
# ## Skenario Pengujian

# %%
df = pd.read_csv("../Dataset/Kontekstual DM/final_processed_data.csv")

# Menampilkan beberapa baris pertama dari dataset
df
# Out:
#        Kode_Jenis_Poliklinik  Kode_Status_Kunjungan_Peserta  Kode_Diagnosis  \
# 0                          1                              2             343
# 1                          1                              2             516
# 2                          1                              2             656
# 3                          1                              2             890
# 4                          1                              2             754
# ...                      ...                            ...             ...
# 25593                      1                              1            1817
# 25594                      1                              1            1817
# 25595                      1                              1            1817
# 25596                      1                              1            1818
# 25597                      1                              1            1818
#
# ...

# %%
#!pip install imbalanced-learn

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, log_loss, accuracy_score, classification_report, confusion_matrix
import xgboost as xgb
from imblearn.pipeline import Pipeline  # Gunakan pipeline dari imblearn 

def assign_weight(label):
    if label == 0:
        return 2
    elif label == 4:
        return 11
    elif label == 3:
        return 40
    elif label == 2:
        return 7
    else:
        return 1  

# Tambahkan kolom bobot ke DataFrame
df['Weight'] = df['Label'].apply(assign_weight)

# Memilih atribut yang akan digunakan sebagai fitur
feature_columns = ['Kode_Jenis_Poliklinik', 
                   'Kode_Diagnosis', 
                   'Kode_Jenis_Kunjungan',
                   'Kode_Provinsi_faskes_tujuan_rujukan',
                   'Kode_Kepemilikan_faskes',
                   'Kode_Jenis_faskes',
                   'Kode_Tipe_faskes',
                   'Kode_Poli_faskes']

# Memisahkan fitur dan target
X = df[feature_columns]  # Hanya kolom fitur yang diinginkan
y = df['Label']          # Target adalah kolom Label
weights = df['Weight']

# Pertama, bagi dataset menjadi train (70%) dan sisa (30%)
X_train, X_temp, y_train, y_temp, w_train, w_temp = train_test_split(
    X, y, weights, test_size=0.3, random_state=42
)

# Kemudian, bagi sisa (30%) menjadi validation (15%) dan test (15%)
X_val, X_test, y_val, y_test, w_val, w_test = train_test_split(
    X_temp, y_temp, w_temp, test_size=0.5, random_state=42
)

# Normalisasi data dengan StandardScaler
scaler = StandardScaler()

# Skala data
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Menghitung total bobot per label
# Mengalikan jumlah data dengan bobot per kelas
class_weight_df = df.groupby('Label').apply(lambda x: (x['Weight'] * x['Weight']).sum()).reset_index()
class_weight_df.columns = ['Class', 'Total Weight']

# Visualisasi distribusi total bobot per label
plt.figure(figsize=(10, 6))
sns.barplot(x='Class', y='Total Weight', data=class_weight_df, palette='viridis')

plt.title("Total Bobot berdasarkan Status Kunjungan Peserta")
plt.xlabel("Status Kunjungan Peserta")
plt.ylabel("Total Bobot")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Rebecca YBS\AppData\Local\Temp\ipykernel_24268\489652995.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   class_weight_df = df.groupby('Label').apply(lambda x: (x['Weight'] * x['Weight']).sum()).reset_index()
# C:\Users\Rebecca YBS\AppData\Local\Temp\ipykernel_24268\489652995.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='Total Weight', data=class_weight_df, palette='viridis')

# %% [markdown]
# ## Membangun Model (Healt-Sick Classification)

# %%
# pip install --upgrade xgboost

# %%
# Konversi dataset ke format DMatrix (opsional untuk XGBoost)
dtrain = xgb.DMatrix(X_train_scaled, label=y_train, weight=w_train)
dval = xgb.DMatrix(X_val_scaled, label=y_val, weight=w_val)
dtest = xgb.DMatrix(X_test_scaled, label=y_test, weight=w_test)

# %%
# Parameter grid untuk pencarian hyperparameter
param_grid = {
    'model__max_depth': [4, 5, 6, 8],
    'model__learning_rate': [0.3, 0.2],
    'model__n_estimators': [200, 300]
}

# %%
# Membuat pipeline yang mencakup scaler dan model XGBoost
pipeline = Pipeline([
    ('model', xgb.XGBClassifier(objective='multi:softprob', num_class=5, eval_metric='mlogloss', random_state=42))  # Model XGBoost
])

# %%
from sklearn.metrics import make_scorer, log_loss
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# Tetapkan scorer log_loss untuk multi-class
scorer = make_scorer(
    lambda y_true, y_pred: log_loss(y_true, y_pred, labels=np.unique(y_train)), 
    greater_is_better=False, needs_proba=True
)

# Gunakan StratifiedKFold untuk validasi silang
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Menjalankan GridSearchCV
grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=cv,
    scoring=scorer,
    verbose=1,
    n_jobs=-1,
    error_score='raise'
)

# Latih model dengan bobot
grid_search.fit(X_train, y_train, model__sample_weight=w_train)

# Menampilkan hasil terbaik
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)

# Gunakan grid_search.best_estimator_ untuk mendapatkan model terbaik
best_model = grid_search.best_estimator_
# Out:
# C:\Users\Rebecca YBS\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best Parameters: {'model__learning_rate': 0.2, 'model__max_depth': 4, 'model__n_estimators': 200}
# Best Score: -0.08418287782830468

# %% [markdown]
# ## Evaluation

# %%
# Prediksi pada data validasi
y_val_pred_prob = best_model.predict_proba(X_val)
y_val_pred = y_val_pred_prob.argmax(axis=1)

# Evaluasi pada data validasi
accuracy_val = accuracy_score(y_val, y_val_pred)
print("Validation Accuracy:", accuracy_val)

print("Validation Classification Report:")
print(classification_report(y_val, y_val_pred))

print("Validation Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))
# Out:
# Validation Accuracy: 0.9658854166666667
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92       762
#            1       1.00      1.00      1.00      3001
#            2       0.24      0.30      0.26        57
#            3       1.00      1.00      1.00         3
#            4       0.03      0.06      0.04        17
#
#     accuracy                           0.97      3840
#    macro avg       0.64      0.65      0.64      3840
# weighted avg       0.97      0.97      0.97      3840
#
# Validation Confusion Matrix:
# [[ 687    0   48    0   27]
#  [   0 3001    0    0    0]
#  [  28    0   17    0   12]
#  [   0    0    0    3    0]
#  [   9    0    7    0    1]]

# %%
# Prediksi pada data uji
y_pred_prob = grid_search.best_estimator_.predict_proba(X_test)

# Ambil indeks dengan probabilitas tertinggi sebagai prediksi akhir
y_pred = y_pred_prob.argmax(axis=1)

# Evaluasi performa
accuracy = accuracy_score(y_test, y_pred)
print("Akurasi:", accuracy)

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Akurasi: 0.9661458333333334
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       769
#            1       1.00      1.00      1.00      2986
#            2       0.20      0.25      0.22        57
#            3       1.00      1.00      1.00         1
#            4       0.22      0.37      0.28        27
#
#     accuracy                           0.97      3840
#    macro avg       0.67      0.70      0.69      3840
# weighted avg       0.97      0.97      0.97      3840
#
# Confusion Matrix:
# [[ 699    0   47    0   23]
#  [   0 2986    0    0    0]
#  [  31    0   14    0   12]
#  [   0    0    0    1    0]
#  [   9    0    8    0   10]]

# %% [markdown]
# # Deployment

# %%
# !pip install dill

# %%
import dill

# Save the model
dill.dump(grid_search, open("mdl.pkl", "wb"))
